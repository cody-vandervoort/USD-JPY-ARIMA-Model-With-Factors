# %%
import pandas as pd

# %%
x1 = pd.read_csv('xrp.csv')
x1.columns = ['ds', 'OPEN', 'HIGH', 'LOW', 'yhat',]
x1['ds']= pd.to_datetime(x1['ds'])
x1['ds'].dt.tz_localize(None),
x1["ds"] = x1["ds"].dt.strftime("%Y-%m-%d %H:%M:%S")
x1 = x1.set_index(pd.DatetimeIndex(x1['ds']))

# %%
del x1['OPEN']
del x1['HIGH']
del x1['LOW']
del x1['ds']
x1.columns = ['xrp']
x1 = x1.iloc[-500:]
x1.to_csv('xrp.csv')

# %%
x1
# Out:
#                         xrp
# ds
# 2021-04-11 12:00:00  1.3771
# 2021-04-11 16:00:00  1.4018
# 2021-04-11 20:00:00  1.3521
# 2021-04-12 00:00:00  1.3478
# 2021-04-12 04:00:00  1.4044
# ...                     ...
# 2021-07-03 00:00:00  0.6468
# 2021-07-03 04:00:00  0.6772
# 2021-07-03 08:00:00  0.6697
# 2021-07-03 12:00:00  0.6739
# 2021-07-03 16:00:00  0.6726
#
# [500 rows x 1 columns]

# %%
x1['ds'].dt.tz_localize(None),
x1["ds"] = x1["ds"].dt.strftime("%Y-%m-%d %H:%M:%S")
#x1 = x1.set_index(pd.DatetimeIndex(x1['ds']))

# %%
del x1['OPEN']
del x1['HIGH']
del x1['LOW']
del x1['ds']
x1.columns = ['btc']
x1 = x1.iloc[-500:]
x1.to_csv('btc.csv')

# %%
x1 = pd.read_csv('eos.csv')
x1.columns = ['ds', 'OPEN', 'HIGH', 'LOW', 'yhat',]
x1['ds']= pd.to_datetime(x1['ds'])
x1['ds'].dt.tz_localize(None),
x1["ds"] = x1["ds"].dt.strftime("%Y-%m-%d %H:%M:%S")
#x1 = x1.set_index(pd.DatetimeIndex(x1['ds']))

# %%
del x1['OPEN']
del x1['HIGH']
del x1['LOW']
del x1['ds']
x1.columns = ['eos']
x1 = x1.iloc[-500:]
x1.to_csv('eos.csv')

# %%
x1 = pd.read_csv('eth.csv')
x1.columns = ['ds', 'OPEN', 'HIGH', 'LOW', 'yhat',]
x1['ds']= pd.to_datetime(x1['ds'])
x1['ds'].dt.tz_localize(None),
x1["ds"] = x1["ds"].dt.strftime("%Y-%m-%d %H:%M:%S")
#x1 = x1.set_index(pd.DatetimeIndex(x1['ds']))

# %%
del x1['OPEN']
del x1['HIGH']
del x1['LOW']
del x1['ds']
x1.columns = ['eth']
x1 = x1.iloc[-500:]
x1.to_csv('eth.csv')
